# %% [markdown]
# ## Sentiment Analysis <- Encoder only

# %%
import pandas as pd

# modify the column width
pd.set_option('display.max_colwidth', None)

# look at a subset of the movie reviews
data_df = pd.read_csv('../resources/Course Materials/Data/movie_reviews_sentiment.csv')
sentiment_df = \
    data_df[['movie_title', 'movie_info', 'sentiment_vader']] \
        .rename(columns={'movie_title': 'title', 'movie_info': 'info', 'sentiment_vader': 'vader'})
sentiment_df.head()
# Out:
#               title  \
# 0   A Dog's Journey
# 1  A Dog's Way Home
# 2    A Tuba to Cuba
# 3       A Vigilante
# 4             After
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           info  \
# ...

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
    # Check available GPU memory
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
    torch.cuda.empty_cache()  # Clear cache before starting
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple MPS")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU: NVIDIA GeForce GTX 1650 with Max-Q Design
# GPU Memory: 4.29 GB

# %%
# sentiment analysis with hugging face
from transformers import pipeline

# %%
# %%time

# utilize machine's GPU if it has one
sentiment_analyzer = pipeline("sentiment-analysis",
                              model="distilbert/distilbert-base-uncased-finetuned-sst-2-english",
                              device=device,
                              truncation=True)

# Use a batch size so that pipelines can run in parallel
sentiment_scores = sentiment_df['info'].apply(sentiment_analyzer, batch_size=8)

if torch.cuda.is_available():
    print(f"Memory used: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
    
sentiment_scores[:5]
# Out:
# Device set to use cuda
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Memory used: 0.28 GB
# CPU times: total: 3.08 s
# Wall time: 3.98 s
# 0    [{'label': 'POSITIVE', 'score': 0.9982469081878662}]
# 1    [{'label': 'POSITIVE', 'score': 0.9995336532592773}]
# 2    [{'label': 'POSITIVE', 'score': 0.9994434714317322}]
# 3    [{'label': 'POSITIVE', 'score': 0.9994601607322693}]
# 4    [{'label': 'POSITIVE', 'score': 0.9972022771835327}]
# Name: info, dtype: object

# %%
# extract the label and score and create a sentiment score for all reviews
sentiment_df['Label_HF'] = sentiment_scores.apply(lambda x: x[0]['label'])
sentiment_df['Score_HF'] = sentiment_scores.apply(lambda x: x[0]['score'])

# Note: When using 'apply' on a whole dataframe (rather than a series), by default axis=0 which applies lambda to each column
# ...but we want lambda applied to each row -> axis=1
sentiment_df['Sentiment_HF'] = sentiment_df.apply(lambda row: row['Score_HF'] if row['Label_HF'] == 'POSITIVE' else -row['Score_HF'], axis=1)
sentiment_df.head()
# Out:
#               title  \
# 0   A Dog's Journey
# 1  A Dog's Way Home
# 2    A Tuba to Cuba
# 3       A Vigilante
# 4             After
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           info  \
# ...

# %%
sentiment_df.sort_values('Sentiment_HF').head()
# Out:
#                          title  \
# 22                       Braid
# 103  Spider-Man: Far From Home
# 34     Dragged Across Concrete
# 165                  Yesterday
# 102                       Skin
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   info  \
# ...

# %% [markdown]
# ## Named Entity Recognition (NER) <- Encoder only

# %%
import pandas as pd

book_df = pd.read_csv('../resources/Course Materials/Data/childrens_books.csv')
book_df.head()
# Out:
#    Ranking                        Title               Author  Year Rating  \
# 0        1    Where the Wild Things Are       Maurice Sendak  1963   4.25
# 1        2  The Very Hungry Caterpillar           Eric Carle  1969   4.34
# 2        3              The Giving Tree     Shel Silverstein  1964   4.38
# 3        4           Green Eggs and Ham            Dr. Seuss  1960   4.31
# 4        5               Goodnight Moon  Margaret Wise Brown  1947   4.31
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               Description
# ...

# %%
df = book_df[['Title', 'Description']]

# %%
# use find the named entities in each review
ner_analyzer = pipeline("ner",
                        model="dbmdz/bert-large-cased-finetuned-conll03-english",
                        device=device,
                        aggregation_strategy='SIMPLE')

# Look at ne's for first row
ner_analyzer(df.Description[0])
# Out:
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cuda
# [{'entity_group': 'MISC',
#   'score': np.float32(0.9462517),
#   'word': 'Where the Wild Things Are',
#   'start': 0,
#   'end': 25},
#  {'entity_group': 'PER',
#   'score': np.float32(0.9990614),
#   'word': 'Max',
#   'start': 34,
#   'end': 37},
# ...

# %%
list(set([entity['word'] for entity in ner_analyzer(df.Description[0]) if entity['entity_group'] == 'PER']))
# Out:
# ['Sendak', 'Max']

# %%
# Generate a Series of lists of character names 
characters = df['Description'].apply(lambda x: [entity['word'] for entity in ner_analyzer(x) if entity['entity_group'] == 'PER'])
characters
# Out:
# 0                  [Max, Max, Sendak]
# 1                  [##pi, Eric Carle]
# 2                       [Silverstein]
# 3           [Sam - I - Am, Dr. Seuss]
# 4                      [Clement Hurd]
#                    ...
# 95                [Jon J. Muth, Muth]
# 96    [Shel Silverstein, Silverstein]
# 97       [Harry, Sirius Black, Harry]
# 98      [Harry, Harry, Ron, Hermione]
# 99                          [Galdone]
# Name: Description, Length: 100, dtype: object

# %%
# Combine all lists into a single list, handle empty sublist (with dropna) and remove duplicates
unique_characters = (characters
                     .explode()
                     .dropna()
                     .unique()
                     .tolist())

# Filter out everything beginning with '##'...i.e subwords
unique_characters = [name for name in unique_characters if not name.startswith('##')]
len(unique_characters)
# Out:
# 154

# %%
# Get a unique list of all authors
authors = list(set([author for author in book_df['Author']]))
authors
# Out:
# ['Janette Sebring Lowrey',
#  'Margaret Wise Brown',
#  'Crockett Johnson',
#  'Laura Joffe Numeroff',
#  'Else Holmelund Minarik',
#  'Peggy Parish',
#  'Jean de Brunhoff',
#  'Dr. Seuss',
#  'Margery Williams Bianco',
#  'Chris Van Allsburg',
#  'Harry Allard',
#  'Eric Carle',
#  'Paul Galdone',
#  'Munro Leaf',
#  'L. Frank Baum',
#  'Don Freeman',
#  'H.A. Rey',
#  'Janell Cannon',
#  'Antoine de Saint-Exupéry',
#  'P.D. Eastman',
#  'Astrid Lindgren',
#  'E.L. Konigsburg',
#  'Mo Willems',
#  'Judith Viorst',
#  'C.S. Lewis',
#  'David Shannon',
#  'Gene Zion',
#  'Beverly Cleary',
#  'Jon Scieszka',
#  "Madeleine L'Engle",
#  'Arnold Lobel',
#  'Bill Martin Jr. and John Archambault',
#  'Clement Clarke Moore',
#  'Jon Stone',
#  'Ludwig Bemelmans',
#  'Kate DiCamillo',
#  'Maurice Sendak',
#  'J.R.R. Tolkien',
#  'Roald Dahl',
#  'Lynne Reid Banks',
#  'Michael Ende',
#  'Kevin Henkes',
#  'Robert Munsch',
#  'Ezra Jack Keats',
#  'A.A. Milne',
#  'E.B. White',
# ...

# %%
# Filter out all authors from list of characters
unique_characters = [name for name in unique_characters if name not in authors]
print(len(unique_characters))
unique_characters.sort()
unique_characters
# Out:
# 145
# ['A',
#  'A. Milne',
#  'A. Rey',
#  'Alexander',
#  'Alice',
#  'Amelia Bedelia',
#  'Anne',
#  'Anne Shirley',
#  'Aslan',
#  'Atreyu',
#  'B',
#  'Babar',
#  'Basil E. Frankweiler',
#  'Bastian',
#  'Baum',
#  'Becky Thatcher',
#  'Bemelmans',
#  'Big Bad Wolf',
#  'Big Friendly Giant',
#  'Big Nutbrown Hare',
#  'Bilbo',
#  'Bilbo Baggins',
#  'Brown',
#  'Bun',
#  'Burton',
#  'C',
#  'Calvin',
#  'Camilla Cream',
#  'Cat in the Hat',
#  'Charles Wallace',
#  'Charlie',
#  'Charlotte',
#  'Chrysanthemum',
#  'Claudia',
#  'Cleary',
#  'Clement Hurd',
#  'Clifford',
#  'Cord',
#  'Corduroy',
#  'Cowardly Lion',
#  'De Brunhoff',
#  'Despereaux',
#  'Despereaux Tilling',
#  'DiCamillo',
#  'Dorothy',
#  'Dr',
#  'Eeyore',
#  'Elizabeth',
#  'Emily Elizabeth',
#  'Falconer',
#  'Ferdinand',
#  'Freeman',
#  'Frog',
#  'Galdone',
#  'Gandalf',
#  'George',
#  'Grinch',
#  'Grover',
#  'H',
#  'Harold',
#  'Harry',
#  'Harry Potter',
#  'Henkes',
#  'Hermione',
#  'Horton',
# ...

# %% [markdown]
# ## Zero-Shot Classification <- Encoder/Decoder

# %%
books_df = pd.read_csv('../resources/Course Materials/Data/childrens_books.csv')
books_df.head()
# Out:
#    Ranking                        Title               Author  Year Rating  \
# 0        1    Where the Wild Things Are       Maurice Sendak  1963   4.25
# 1        2  The Very Hungry Caterpillar           Eric Carle  1969   4.34
# 2        3              The Giving Tree     Shel Silverstein  1964   4.38
# 3        4           Green Eggs and Ham            Dr. Seuss  1960   4.31
# 4        5               Goodnight Moon  Margaret Wise Brown  1947   4.31
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               Description
# ...

# %%
classifier = pipeline("zero-shot-classification",
                      model="facebook/bart-large-mnli",
                      device='cuda')
# Out:
# Device set to use cuda

# %%
# List of categories ... note: I get different results if I uppercase the category names
categories = ['adventure & fantasy', 'animals & nature', 'mystery', 'humor', 'non-fiction']

classifier(books_df.Description[0], candidate_labels = categories)
# Out:
# {'sequence': "Where the Wild Things Are\xa0follows Max, a young boy who, after being sent to his room for misbehaving, imagines sailing to an island filled with wild creatures. As their king, Max tames the beasts and eventually returns home to find his supper waiting for him. This iconic book explores themes of imagination, adventure, and the complex emotions of childhood, all captured through Sendak's whimsical illustrations and story.",
#  'labels': ['adventure & fantasy',
#   'animals & nature',
#   'humor',
#   'mystery',
#   'non-fiction'],
#  'scores': [0.401902437210083,
#   0.3064911961555481,
#   0.14998993277549744,
#   0.07116298377513885,
#   0.0704534500837326]}

# %%
# First label is the one with highest probability
books_df['Category'] = books_df['Description'].apply(lambda x: classifier(x, candidate_labels = categories)['labels'][0])
books_df[:10]
# Out:
#    Ranking                                    Title                Author  \
# 0        1                Where the Wild Things Are        Maurice Sendak
# 1        2              The Very Hungry Caterpillar            Eric Carle
# 2        3                          The Giving Tree      Shel Silverstein
# 3        4                       Green Eggs and Ham             Dr. Seuss
# 4        5                           Goodnight Moon   Margaret Wise Brown
# 5        6                          Charlotte’s Web            E.B. White
# 6        7  The Cat in the Hat (Cat in the Hat, #1)             Dr. Seuss
# 7        8                  Where the Sidewalk Ends      Shel Silverstein
# 8        9             If You Give a Mouse a Cookie  Laura Joffe Numeroff
# 9       10                         Love You Forever         Robert Munsch
#
#    Year Rating  \
# 0  1963   4.25
# 1  1969   4.34
# 2  1964   4.38
# 3  1960   4.31
# 4  1947   4.31
# 5  1952   4.20
# 6  1957   4.19
# 7  1974   4.34
# ...

# %%
# Returns a Series with category counts
books_df['Category'].value_counts()
# Out:
# Category
# humor                  42
# adventure & fantasy    18
# non-fiction            15
# animals & nature       13
# mystery                12
# Name: count, dtype: int64

# %% [markdown]
# ## Text Summarization <- Encoder/Decoder

# %%
summarizer = pipeline("summarization", 
                      model="facebook/bart-large-cnn", 
                      device='cuda')
# Out:
# Device set to use cuda

# %%
books_df.head()
# Out:
#    Ranking                        Title               Author  Year Rating  \
# 0        1    Where the Wild Things Are       Maurice Sendak  1963   4.25
# 1        2  The Very Hungry Caterpillar           Eric Carle  1969   4.34
# 2        3              The Giving Tree     Shel Silverstein  1964   4.38
# 3        4           Green Eggs and Ham            Dr. Seuss  1960   4.31
# 4        5               Goodnight Moon  Margaret Wise Brown  1947   4.31
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               Description  \
# ...

# %%
summary_df = pd.DataFrame({
    'title': books_df['Title'],
    'description': books_df['Description']
})
# returns a list of dictionaries
summarizer(summary_df.description[0], min_length=20, max_length=50, early_stopping=True, length_penalty=0.8)[0]['summary_text']
# Out:
# 'Where the Wild Things Are follows Max, a young boy who imagines sailing to an island filled with wild creatures. This iconic book explores themes of imagination, adventure, and the complex emotions of childhood.'

# %%
summary_df['summary'] = \
    summary_df['description'] \
        .apply(lambda x: summarizer(x, min_length=20, max_length=60, early_stopping=True, length_penalty=0.8)[0]['summary_text'])
summary_df.head()
# Out:
#                          title  \
# 0    Where the Wild Things Are
# 1  The Very Hungry Caterpillar
# 2              The Giving Tree
# 3           Green Eggs and Ham
# 4               Goodnight Moon
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               description  \
# ...

# %% [markdown]
# ## Document Similarity <- Embeddings

# %%
book_df.head(3)
# Out:
#    Ranking                        Title            Author  Year Rating  \
# 0        1    Where the Wild Things Are    Maurice Sendak  1963   4.25
# 1        2  The Very Hungry Caterpillar        Eric Carle  1969   4.34
# 2        3              The Giving Tree  Shel Silverstein  1964   4.38
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               Description
# ...

# %%
book_df[book_df['Title'].str.startswith('Harry Potter')]
# Out:
#     Ranking                                                        Title  \
# 13       14     Harry Potter and the Sorcerer's Stone (Harry Potter, #1)
# 97       98  Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)
# 98       99   Harry Potter and the Chamber of Secrets (Harry Potter, #2)
#
#           Author  Year Rating  \
# 13  J.K. Rowling  1997   4.47
# 97  J.K. Rowling  1999   4.58
# 98  J.K. Rowling  1998   4.43
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                   Description
# ...

# %%
# extract the embedding representation for each book description
feature_extractor = pipeline("feature-extraction",
                             model="sentence-transformers/all-MiniLM-L6-v2",
                             device='cuda')
# Out:
# Device set to use cuda

# %%
import numpy as np

# get the token embeddings for each book
# ... then use Mean pooling to get sentence embedding
bk_embeddings = book_df['Description'].apply(lambda x: np.mean(np.array(feature_extractor(x)[0]), axis=0))
print(type(bk_embeddings))
print(len(bk_embeddings))
print(bk_embeddings.shape)
book_embeddings = np.vstack(bk_embeddings)
book_embeddings.shape
# Out:
# <class 'pandas.core.series.Series'>
# 100
# (100,)
# (100, 384)

# %%
# get the embeddings for just the 1st Harry Potter book (idx = 13)
# Make sure output numpy array contains 1 row and as many columns as necessary
embedding_hp1 = np.array(book_embeddings[13]).reshape(1, -1)
embedding_hp1.shape
# Out:
# (1, 384)

# %%
# calculate the cosine similarity scores
from sklearn.metrics.pairwise import cosine_similarity

similarity_scores_hp1 = cosine_similarity(embedding_hp1, book_embeddings)
similarity_scores_hp1_series = pd.Series(similarity_scores_hp1.flatten(), name='similarity_score')
similarity_scores_hp1_series.head()
# Out:
# 0    0.260106
# 1    0.304621
# 2    0.160355
# 3    0.194684
# 4    0.243536
# Name: similarity_score, dtype: float64

# %%
# combine book titles, descriptions and scores
similarity_scores_hp1_df = pd.concat([book_df[['Title', 'Description']], similarity_scores_hp1_series], axis=1)
similarity_scores_hp1_df.head()
# Out:
#                          Title  \
# 0    Where the Wild Things Are
# 1  The Very Hungry Caterpillar
# 2              The Giving Tree
# 3           Green Eggs and Ham
# 4               Goodnight Moon
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               Description  \
# ...

# %%
# view the top 5 most similar books (excluding HP #1 itself)
similarity_scores_hp1_df.sort_values('similarity_score', ascending=False)[1:6]
# Out:
#                                                           Title  \
# 98   Harry Potter and the Chamber of Secrets (Harry Potter, #2)
# 97  Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)
# 63                                                  The Witches
# 35    The Chronicles of Narnia (The Chronicles of Narnia, #1-7)
# 55                          The Wonderful Wizard of Oz (Oz, #1)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                           Description  \
# ...
